# %%
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype

# %%
df=pd.read_csv('F:\Hajara\Data_Science\Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
len(df.index)
# Out:
# 16719

# %%
df['Year_of_Release'].isnull().values.any()
# Out:
# True

# %%
df['Year_of_Release'].isnull().sum()
# Out:
# 269

# %%
df[df['Year_of_Release'].isnull()==True]
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP              NaN
# 16409                      Freaky Flyers       GC              NaN
# 16452                          Inversion       PC              NaN
# 16462        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16526                       Virtua Quest       GC              NaN
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# ...

# %%
df1=pd.read_csv('F:\Hajara\Data_Science\Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df2 = df1[df1['Year_of_Release'].isnull()==True]

# %%
df2
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP              NaN
# 16409                      Freaky Flyers       GC              NaN
# 16452                          Inversion       PC              NaN
# 16462        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16526                       Virtua Quest       GC              NaN
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# ...

# %%
df2['Name'].str[-4:]
# Out:
# 183      2004
# 377      2004
# 456      game
# 475      2006
# 609      ders
#          ...
# 16376    2008
# 16409    yers
# 16452    sion
# 16462    itan
# 16526    uest
# Name: Name, Length: 269, dtype: object

# %%
df2['year'] = df2.apply(lambda x=df2['Name'].str[-4:] : pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))
# Out:
# <ipython-input-99-b1194b17b807>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year'] = df2.apply(lambda x=df2['Name'].str[-4:] : pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))

# %%
df2.Name.str.extract('(\d+)')
# Out:
#           0
# 183    2004
# 377    2004
# 456     NaN
# 475    2006
# 609     NaN
# ...     ...
# 16376  2008
# 16409   NaN
# 16452   NaN
# 16462   NaN
# 16526   NaN
#
# [269 rows x 1 columns]

# %%
df2.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating',
#        'Year_with_4_digits', 'year'],
#       dtype='object')

# %%
df2.apply(lambda x=df2.Name.str.extract('(\d+)') :pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))
#df2['year'] = pd.to_numeric(df2.Name.str.extract('(\d+)'), errors='coerce')
# Out:
#        Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 183     NaN       NaN              NaN    NaN        NaN      4.26      0.26
# 377     NaN       NaN              NaN    NaN        NaN      0.59      2.36
# 456     NaN       NaN              NaN    NaN        NaN      1.80      0.97
# 475     NaN       NaN              NaN    NaN        NaN      1.57      1.02
# 609     NaN    2600.0              NaN    NaN        NaN      2.36      0.14
# ...     ...       ...              ...    ...        ...       ...       ...
# 16376   NaN       NaN              NaN    NaN        NaN      0.01      0.00
# 16409   NaN       NaN              NaN    NaN        NaN      0.01      0.00
# 16452   NaN       NaN              NaN    NaN        NaN      0.01      0.00
# 16462   NaN       NaN              NaN    NaN        NaN      0.01      0.00
# 16526   NaN       NaN              NaN    NaN        NaN      0.01      0.00
#
# ...

# %%
df.apply(lambda x=df[df['Year_of_Release'].isnull()==True]['Name'].str[-4:] : pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))
#df2 = df1.apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))
# Out:
#        Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0       NaN       NaN           2006.0    NaN        NaN     41.36     28.96
# 1       NaN       NaN           1985.0    NaN        NaN     29.08      3.58
# 2       NaN       NaN           2008.0    NaN        NaN     15.68     12.76
# 3       NaN       NaN           2009.0    NaN        NaN     15.61     10.93
# 4       NaN       NaN           1996.0    NaN        NaN     11.27      8.89
# ...     ...       ...              ...    ...        ...       ...       ...
# 16714   NaN       NaN           2016.0    NaN        NaN      0.00      0.00
# 16715   NaN       NaN           2006.0    NaN        NaN      0.00      0.01
# 16716   NaN       NaN           2016.0    NaN        NaN      0.00      0.00
# 16717   NaN       NaN           2003.0    NaN        NaN      0.01      0.00
# 16718   NaN       NaN           2016.0    NaN        NaN      0.00      0.00
#
# ...

# %%
df2
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP              NaN
# 16409                      Freaky Flyers       GC              NaN
# 16452                          Inversion       PC              NaN
# 16462        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16526                       Virtua Quest       GC              NaN
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# ...
